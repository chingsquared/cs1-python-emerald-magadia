# %% [markdown]
# <a href="https://colab.research.google.com/github/chingsquared/cs1-python-emerald-magadia/blob/main/fa3programming.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = (input("Name: "))
age = (input("Age: "))
course = (input("Course: "))
# Out:
# Name: mia
# Age: 9
# Course: Med

# %%
score = int(input("Score: "))

if score <= 75:
  print("Failed")

else:
  print("Passed")
# Out:
# Score: 89
# Pass

# %%
name = (input("Name: "))
score = int(input("Score:"))

if score >= 90 and score <= 100:
  print("A")

elif score >= 80 and score <= 89:
  print("B")

elif score >= 70 and score <= 79:
  print("C")

elif score <= 70:
  print("F")
# Out:
# Name: Mia
# Score:98
# A
