# %% [markdown]
# <a href="https://colab.research.google.com/github/chingsquared/cs1-python-emerald-magadia/blob/main/hello.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("hello g7 emerald!")
# Out:
# hello g7 emerald!
